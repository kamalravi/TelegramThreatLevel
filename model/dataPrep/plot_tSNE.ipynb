# %%
import pickle

# %%
# Open the file in binary mode
def read_pkl(fname):
    with open(fname, 'rb') as file:
        # Call load method to deserialze
        return pickle.load(file)

# %%
features = read_pkl("/home/ravi/PROJECTS_DATA/DataModelsResults/Results/tSNE/features_KFold_1.pkl")
labels = read_pkl("/home/ravi/PROJECTS_DATA/DataModelsResults/Results/tSNE/labels_KFold_1.pkl")

# %%
features.shape
# Out:
# (325406, 7523484)

# %%
labels.shape
# Out:
# (325406,)

# %%
from tsne import tsne

# %%
from sklearn.manifold import TSNE
from numpy import reshape
import seaborn as sns
import pandas as pd

# %%
x = features
y = labels

# %%
tsne = TSNE(n_components=2, verbose=1, random_state=42)
z = tsne.fit_transform(x)
# Out:
# /home/ravi/miniconda3/envs/redditJournal/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ravi/miniconda3/envs/redditJournal/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 325406 samples in 1.469s...
# [t-SNE] Computed neighbors for 325406 samples in 44556.191s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 325406
# [t-SNE] Computed conditional probabilities for sample 2000 / 325406
# [t-SNE] Computed conditional probabilities for sample 3000 / 325406
# [t-SNE] Computed conditional probabilities for sample 4000 / 325406
# [t-SNE] Computed conditional probabilities for sample 5000 / 325406
# [t-SNE] Computed conditional probabilities for sample 6000 / 325406
# [t-SNE] Computed conditional probabilities for sample 7000 / 325406
# [t-SNE] Computed conditional probabilities for sample 8000 / 325406
# [t-SNE] Computed conditional probabilities for sample 9000 / 325406
# [t-SNE] Computed conditional probabilities for sample 10000 / 325406
# [t-SNE] Computed conditional probabilities for sample 11000 / 325406
# [t-SNE] Computed conditional probabilities for sample 12000 / 325406
# [t-SNE] Computed conditional probabilities for sample 13000 / 325406
# [t-SNE] Computed conditional probabilities for sample 14000 / 325406
# [t-SNE] Computed conditional probabilities for sample 15000 / 325406
# [t-SNE] Computed conditional probabilities for sample 16000 / 325406
# [t-SNE] Computed conditional probabilities for sample 17000 / 325406
# [t-SNE] Computed conditional probabilities for sample 18000 / 325406
# [t-SNE] Computed conditional probabilities for sample 19000 / 325406
# [t-SNE] Computed conditional probabilities for sample 20000 / 325406
# [t-SNE] Computed conditional probabilities for sample 21000 / 325406
# [t-SNE] Computed conditional probabilities for sample 22000 / 325406
# [t-SNE] Computed conditional probabilities for sample 23000 / 325406
# [t-SNE] Computed conditional probabilities for sample 24000 / 325406
# [t-SNE] Computed conditional probabilities for sample 25000 / 325406
# [t-SNE] Computed conditional probabilities for sample 26000 / 325406
# [t-SNE] Computed conditional probabilities for sample 27000 / 325406
# [t-SNE] Computed conditional probabilities for sample 28000 / 325406
# [t-SNE] Computed conditional probabilities for sample 29000 / 325406
# [t-SNE] Computed conditional probabilities for sample 30000 / 325406
# [t-SNE] Computed conditional probabilities for sample 31000 / 325406
# [t-SNE] Computed conditional probabilities for sample 32000 / 325406
# [t-SNE] Computed conditional probabilities for sample 33000 / 325406
# [t-SNE] Computed conditional probabilities for sample 34000 / 325406
# [t-SNE] Computed conditional probabilities for sample 35000 / 325406
# [t-SNE] Computed conditional probabilities for sample 36000 / 325406
# [t-SNE] Computed conditional probabilities for sample 37000 / 325406
# [t-SNE] Computed conditional probabilities for sample 38000 / 325406
# [t-SNE] Computed conditional probabilities for sample 39000 / 325406
# [t-SNE] Computed conditional probabilities for sample 40000 / 325406
# [t-SNE] Computed conditional probabilities for sample 41000 / 325406
# [t-SNE] Computed conditional probabilities for sample 42000 / 325406
# [t-SNE] Computed conditional probabilities for sample 43000 / 325406
# [t-SNE] Computed conditional probabilities for sample 44000 / 325406
# [t-SNE] Computed conditional probabilities for sample 45000 / 325406
# [t-SNE] Computed conditional probabilities for sample 46000 / 325406
# [t-SNE] Computed conditional probabilities for sample 47000 / 325406
# [t-SNE] Computed conditional probabilities for sample 48000 / 325406
# [t-SNE] Computed conditional probabilities for sample 49000 / 325406
# [t-SNE] Computed conditional probabilities for sample 50000 / 325406
# [t-SNE] Computed conditional probabilities for sample 51000 / 325406
# [t-SNE] Computed conditional probabilities for sample 52000 / 325406
# [t-SNE] Computed conditional probabilities for sample 53000 / 325406
# [t-SNE] Computed conditional probabilities for sample 54000 / 325406
# [t-SNE] Computed conditional probabilities for sample 55000 / 325406
# [t-SNE] Computed conditional probabilities for sample 56000 / 325406
# [t-SNE] Computed conditional probabilities for sample 57000 / 325406
# [t-SNE] Computed conditional probabilities for sample 58000 / 325406
# [t-SNE] Computed conditional probabilities for sample 59000 / 325406
# [t-SNE] Computed conditional probabilities for sample 60000 / 325406
# [t-SNE] Computed conditional probabilities for sample 61000 / 325406
# [t-SNE] Computed conditional probabilities for sample 62000 / 325406
# [t-SNE] Computed conditional probabilities for sample 63000 / 325406
# [t-SNE] Computed conditional probabilities for sample 64000 / 325406
# [t-SNE] Computed conditional probabilities for sample 65000 / 325406
# [t-SNE] Computed conditional probabilities for sample 66000 / 325406
# [t-SNE] Computed conditional probabilities for sample 67000 / 325406
# [t-SNE] Computed conditional probabilities for sample 68000 / 325406
# [t-SNE] Computed conditional probabilities for sample 69000 / 325406
# [t-SNE] Computed conditional probabilities for sample 70000 / 325406
# [t-SNE] Computed conditional probabilities for sample 71000 / 325406
# [t-SNE] Computed conditional probabilities for sample 72000 / 325406
# [t-SNE] Computed conditional probabilities for sample 73000 / 325406
# [t-SNE] Computed conditional probabilities for sample 74000 / 325406
# [t-SNE] Computed conditional probabilities for sample 75000 / 325406
# [t-SNE] Computed conditional probabilities for sample 76000 / 325406
# [t-SNE] Computed conditional probabilities for sample 77000 / 325406
# [t-SNE] Computed conditional probabilities for sample 78000 / 325406
# [t-SNE] Computed conditional probabilities for sample 79000 / 325406
# [t-SNE] Computed conditional probabilities for sample 80000 / 325406
# [t-SNE] Computed conditional probabilities for sample 81000 / 325406
# [t-SNE] Computed conditional probabilities for sample 82000 / 325406
# [t-SNE] Computed conditional probabilities for sample 83000 / 325406
# [t-SNE] Computed conditional probabilities for sample 84000 / 325406
# [t-SNE] Computed conditional probabilities for sample 85000 / 325406
# [t-SNE] Computed conditional probabilities for sample 86000 / 325406
# [t-SNE] Computed conditional probabilities for sample 87000 / 325406
# [t-SNE] Computed conditional probabilities for sample 88000 / 325406
# [t-SNE] Computed conditional probabilities for sample 89000 / 325406
# [t-SNE] Computed conditional probabilities for sample 90000 / 325406
# [t-SNE] Computed conditional probabilities for sample 91000 / 325406
# [t-SNE] Computed conditional probabilities for sample 92000 / 325406
# [t-SNE] Computed conditional probabilities for sample 93000 / 325406
# [t-SNE] Computed conditional probabilities for sample 94000 / 325406
# [t-SNE] Computed conditional probabilities for sample 95000 / 325406
# [t-SNE] Computed conditional probabilities for sample 96000 / 325406
# [t-SNE] Computed conditional probabilities for sample 97000 / 325406
# [t-SNE] Computed conditional probabilities for sample 98000 / 325406
# [t-SNE] Computed conditional probabilities for sample 99000 / 325406
# [t-SNE] Computed conditional probabilities for sample 100000 / 325406
# [t-SNE] Computed conditional probabilities for sample 101000 / 325406
# [t-SNE] Computed conditional probabilities for sample 102000 / 325406
# [t-SNE] Computed conditional probabilities for sample 103000 / 325406
# [t-SNE] Computed conditional probabilities for sample 104000 / 325406
# [t-SNE] Computed conditional probabilities for sample 105000 / 325406
# [t-SNE] Computed conditional probabilities for sample 106000 / 325406
# [t-SNE] Computed conditional probabilities for sample 107000 / 325406
# [t-SNE] Computed conditional probabilities for sample 108000 / 325406
# [t-SNE] Computed conditional probabilities for sample 109000 / 325406
# [t-SNE] Computed conditional probabilities for sample 110000 / 325406
# [t-SNE] Computed conditional probabilities for sample 111000 / 325406
# [t-SNE] Computed conditional probabilities for sample 112000 / 325406
# [t-SNE] Computed conditional probabilities for sample 113000 / 325406
# [t-SNE] Computed conditional probabilities for sample 114000 / 325406
# [t-SNE] Computed conditional probabilities for sample 115000 / 325406
# [t-SNE] Computed conditional probabilities for sample 116000 / 325406
# [t-SNE] Computed conditional probabilities for sample 117000 / 325406
# [t-SNE] Computed conditional probabilities for sample 118000 / 325406
# [t-SNE] Computed conditional probabilities for sample 119000 / 325406
# [t-SNE] Computed conditional probabilities for sample 120000 / 325406
# [t-SNE] Computed conditional probabilities for sample 121000 / 325406
# [t-SNE] Computed conditional probabilities for sample 122000 / 325406
# [t-SNE] Computed conditional probabilities for sample 123000 / 325406
# [t-SNE] Computed conditional probabilities for sample 124000 / 325406
# [t-SNE] Computed conditional probabilities for sample 125000 / 325406
# [t-SNE] Computed conditional probabilities for sample 126000 / 325406
# [t-SNE] Computed conditional probabilities for sample 127000 / 325406
# [t-SNE] Computed conditional probabilities for sample 128000 / 325406
# [t-SNE] Computed conditional probabilities for sample 129000 / 325406
# [t-SNE] Computed conditional probabilities for sample 130000 / 325406
# [t-SNE] Computed conditional probabilities for sample 131000 / 325406
# [t-SNE] Computed conditional probabilities for sample 132000 / 325406
# [t-SNE] Computed conditional probabilities for sample 133000 / 325406
# [t-SNE] Computed conditional probabilities for sample 134000 / 325406
# [t-SNE] Computed conditional probabilities for sample 135000 / 325406
# [t-SNE] Computed conditional probabilities for sample 136000 / 325406
# [t-SNE] Computed conditional probabilities for sample 137000 / 325406
# [t-SNE] Computed conditional probabilities for sample 138000 / 325406
# [t-SNE] Computed conditional probabilities for sample 139000 / 325406
# [t-SNE] Computed conditional probabilities for sample 140000 / 325406
# [t-SNE] Computed conditional probabilities for sample 141000 / 325406
# [t-SNE] Computed conditional probabilities for sample 142000 / 325406
# [t-SNE] Computed conditional probabilities for sample 143000 / 325406
# [t-SNE] Computed conditional probabilities for sample 144000 / 325406
# [t-SNE] Computed conditional probabilities for sample 145000 / 325406
# [t-SNE] Computed conditional probabilities for sample 146000 / 325406
# [t-SNE] Computed conditional probabilities for sample 147000 / 325406
# [t-SNE] Computed conditional probabilities for sample 148000 / 325406
# [t-SNE] Computed conditional probabilities for sample 149000 / 325406
# [t-SNE] Computed conditional probabilities for sample 150000 / 325406
# [t-SNE] Computed conditional probabilities for sample 151000 / 325406
# [t-SNE] Computed conditional probabilities for sample 152000 / 325406
# [t-SNE] Computed conditional probabilities for sample 153000 / 325406
# [t-SNE] Computed conditional probabilities for sample 154000 / 325406
# [t-SNE] Computed conditional probabilities for sample 155000 / 325406
# [t-SNE] Computed conditional probabilities for sample 156000 / 325406
# [t-SNE] Computed conditional probabilities for sample 157000 / 325406
# [t-SNE] Computed conditional probabilities for sample 158000 / 325406
# [t-SNE] Computed conditional probabilities for sample 159000 / 325406
# [t-SNE] Computed conditional probabilities for sample 160000 / 325406
# [t-SNE] Computed conditional probabilities for sample 161000 / 325406
# [t-SNE] Computed conditional probabilities for sample 162000 / 325406
# [t-SNE] Computed conditional probabilities for sample 163000 / 325406
# [t-SNE] Computed conditional probabilities for sample 164000 / 325406
# [t-SNE] Computed conditional probabilities for sample 165000 / 325406
# [t-SNE] Computed conditional probabilities for sample 166000 / 325406
# [t-SNE] Computed conditional probabilities for sample 167000 / 325406
# [t-SNE] Computed conditional probabilities for sample 168000 / 325406
# [t-SNE] Computed conditional probabilities for sample 169000 / 325406
# [t-SNE] Computed conditional probabilities for sample 170000 / 325406
# [t-SNE] Computed conditional probabilities for sample 171000 / 325406
# [t-SNE] Computed conditional probabilities for sample 172000 / 325406
# [t-SNE] Computed conditional probabilities for sample 173000 / 325406
# [t-SNE] Computed conditional probabilities for sample 174000 / 325406
# [t-SNE] Computed conditional probabilities for sample 175000 / 325406
# [t-SNE] Computed conditional probabilities for sample 176000 / 325406
# [t-SNE] Computed conditional probabilities for sample 177000 / 325406
# [t-SNE] Computed conditional probabilities for sample 178000 / 325406
# [t-SNE] Computed conditional probabilities for sample 179000 / 325406
# [t-SNE] Computed conditional probabilities for sample 180000 / 325406
# [t-SNE] Computed conditional probabilities for sample 181000 / 325406
# [t-SNE] Computed conditional probabilities for sample 182000 / 325406
# [t-SNE] Computed conditional probabilities for sample 183000 / 325406
# [t-SNE] Computed conditional probabilities for sample 184000 / 325406
# [t-SNE] Computed conditional probabilities for sample 185000 / 325406
# [t-SNE] Computed conditional probabilities for sample 186000 / 325406
# [t-SNE] Computed conditional probabilities for sample 187000 / 325406
# [t-SNE] Computed conditional probabilities for sample 188000 / 325406
# [t-SNE] Computed conditional probabilities for sample 189000 / 325406
# [t-SNE] Computed conditional probabilities for sample 190000 / 325406
# [t-SNE] Computed conditional probabilities for sample 191000 / 325406
# [t-SNE] Computed conditional probabilities for sample 192000 / 325406
# [t-SNE] Computed conditional probabilities for sample 193000 / 325406
# [t-SNE] Computed conditional probabilities for sample 194000 / 325406
# [t-SNE] Computed conditional probabilities for sample 195000 / 325406
# [t-SNE] Computed conditional probabilities for sample 196000 / 325406
# [t-SNE] Computed conditional probabilities for sample 197000 / 325406
# [t-SNE] Computed conditional probabilities for sample 198000 / 325406
# [t-SNE] Computed conditional probabilities for sample 199000 / 325406
# [t-SNE] Computed conditional probabilities for sample 200000 / 325406
# [t-SNE] Computed conditional probabilities for sample 201000 / 325406
# [t-SNE] Computed conditional probabilities for sample 202000 / 325406
# [t-SNE] Computed conditional probabilities for sample 203000 / 325406
# [t-SNE] Computed conditional probabilities for sample 204000 / 325406
# [t-SNE] Computed conditional probabilities for sample 205000 / 325406
# [t-SNE] Computed conditional probabilities for sample 206000 / 325406
# [t-SNE] Computed conditional probabilities for sample 207000 / 325406
# [t-SNE] Computed conditional probabilities for sample 208000 / 325406
# [t-SNE] Computed conditional probabilities for sample 209000 / 325406
# [t-SNE] Computed conditional probabilities for sample 210000 / 325406
# [t-SNE] Computed conditional probabilities for sample 211000 / 325406
# [t-SNE] Computed conditional probabilities for sample 212000 / 325406
# [t-SNE] Computed conditional probabilities for sample 213000 / 325406
# [t-SNE] Computed conditional probabilities for sample 214000 / 325406
# [t-SNE] Computed conditional probabilities for sample 215000 / 325406
# [t-SNE] Computed conditional probabilities for sample 216000 / 325406
# [t-SNE] Computed conditional probabilities for sample 217000 / 325406
# [t-SNE] Computed conditional probabilities for sample 218000 / 325406
# [t-SNE] Computed conditional probabilities for sample 219000 / 325406
# [t-SNE] Computed conditional probabilities for sample 220000 / 325406
# [t-SNE] Computed conditional probabilities for sample 221000 / 325406
# [t-SNE] Computed conditional probabilities for sample 222000 / 325406
# [t-SNE] Computed conditional probabilities for sample 223000 / 325406
# [t-SNE] Computed conditional probabilities for sample 224000 / 325406
# [t-SNE] Computed conditional probabilities for sample 225000 / 325406
# [t-SNE] Computed conditional probabilities for sample 226000 / 325406
# [t-SNE] Computed conditional probabilities for sample 227000 / 325406
# [t-SNE] Computed conditional probabilities for sample 228000 / 325406
# [t-SNE] Computed conditional probabilities for sample 229000 / 325406
# [t-SNE] Computed conditional probabilities for sample 230000 / 325406
# [t-SNE] Computed conditional probabilities for sample 231000 / 325406
# [t-SNE] Computed conditional probabilities for sample 232000 / 325406
# [t-SNE] Computed conditional probabilities for sample 233000 / 325406
# [t-SNE] Computed conditional probabilities for sample 234000 / 325406
# [t-SNE] Computed conditional probabilities for sample 235000 / 325406
# [t-SNE] Computed conditional probabilities for sample 236000 / 325406
# [t-SNE] Computed conditional probabilities for sample 237000 / 325406
# [t-SNE] Computed conditional probabilities for sample 238000 / 325406
# [t-SNE] Computed conditional probabilities for sample 239000 / 325406
# [t-SNE] Computed conditional probabilities for sample 240000 / 325406
# [t-SNE] Computed conditional probabilities for sample 241000 / 325406
# [t-SNE] Computed conditional probabilities for sample 242000 / 325406
# [t-SNE] Computed conditional probabilities for sample 243000 / 325406
# [t-SNE] Computed conditional probabilities for sample 244000 / 325406
# [t-SNE] Computed conditional probabilities for sample 245000 / 325406
# [t-SNE] Computed conditional probabilities for sample 246000 / 325406
# [t-SNE] Computed conditional probabilities for sample 247000 / 325406
# [t-SNE] Computed conditional probabilities for sample 248000 / 325406
# [t-SNE] Computed conditional probabilities for sample 249000 / 325406
# [t-SNE] Computed conditional probabilities for sample 250000 / 325406
# [t-SNE] Computed conditional probabilities for sample 251000 / 325406
# [t-SNE] Computed conditional probabilities for sample 252000 / 325406
# [t-SNE] Computed conditional probabilities for sample 253000 / 325406
# [t-SNE] Computed conditional probabilities for sample 254000 / 325406
# [t-SNE] Computed conditional probabilities for sample 255000 / 325406
# [t-SNE] Computed conditional probabilities for sample 256000 / 325406
# [t-SNE] Computed conditional probabilities for sample 257000 / 325406
# [t-SNE] Computed conditional probabilities for sample 258000 / 325406
# [t-SNE] Computed conditional probabilities for sample 259000 / 325406
# [t-SNE] Computed conditional probabilities for sample 260000 / 325406
# [t-SNE] Computed conditional probabilities for sample 261000 / 325406
# [t-SNE] Computed conditional probabilities for sample 262000 / 325406
# [t-SNE] Computed conditional probabilities for sample 263000 / 325406
# [t-SNE] Computed conditional probabilities for sample 264000 / 325406
# [t-SNE] Computed conditional probabilities for sample 265000 / 325406
# [t-SNE] Computed conditional probabilities for sample 266000 / 325406
# [t-SNE] Computed conditional probabilities for sample 267000 / 325406
# [t-SNE] Computed conditional probabilities for sample 268000 / 325406
# [t-SNE] Computed conditional probabilities for sample 269000 / 325406
# [t-SNE] Computed conditional probabilities for sample 270000 / 325406
# [t-SNE] Computed conditional probabilities for sample 271000 / 325406
# [t-SNE] Computed conditional probabilities for sample 272000 / 325406
# [t-SNE] Computed conditional probabilities for sample 273000 / 325406
# [t-SNE] Computed conditional probabilities for sample 274000 / 325406
# [t-SNE] Computed conditional probabilities for sample 275000 / 325406
# [t-SNE] Computed conditional probabilities for sample 276000 / 325406
# [t-SNE] Computed conditional probabilities for sample 277000 / 325406
# [t-SNE] Computed conditional probabilities for sample 278000 / 325406
# [t-SNE] Computed conditional probabilities for sample 279000 / 325406
# [t-SNE] Computed conditional probabilities for sample 280000 / 325406
# [t-SNE] Computed conditional probabilities for sample 281000 / 325406
# [t-SNE] Computed conditional probabilities for sample 282000 / 325406
# [t-SNE] Computed conditional probabilities for sample 283000 / 325406
# [t-SNE] Computed conditional probabilities for sample 284000 / 325406
# [t-SNE] Computed conditional probabilities for sample 285000 / 325406
# [t-SNE] Computed conditional probabilities for sample 286000 / 325406
# [t-SNE] Computed conditional probabilities for sample 287000 / 325406
# [t-SNE] Computed conditional probabilities for sample 288000 / 325406
# [t-SNE] Computed conditional probabilities for sample 289000 / 325406
# [t-SNE] Computed conditional probabilities for sample 290000 / 325406
# [t-SNE] Computed conditional probabilities for sample 291000 / 325406
# [t-SNE] Computed conditional probabilities for sample 292000 / 325406
# [t-SNE] Computed conditional probabilities for sample 293000 / 325406
# [t-SNE] Computed conditional probabilities for sample 294000 / 325406
# [t-SNE] Computed conditional probabilities for sample 295000 / 325406
# [t-SNE] Computed conditional probabilities for sample 296000 / 325406
# [t-SNE] Computed conditional probabilities for sample 297000 / 325406
# [t-SNE] Computed conditional probabilities for sample 298000 / 325406
# [t-SNE] Computed conditional probabilities for sample 299000 / 325406
# [t-SNE] Computed conditional probabilities for sample 300000 / 325406
# [t-SNE] Computed conditional probabilities for sample 301000 / 325406
# [t-SNE] Computed conditional probabilities for sample 302000 / 325406
# [t-SNE] Computed conditional probabilities for sample 303000 / 325406
# [t-SNE] Computed conditional probabilities for sample 304000 / 325406
# [t-SNE] Computed conditional probabilities for sample 305000 / 325406
# [t-SNE] Computed conditional probabilities for sample 306000 / 325406
# [t-SNE] Computed conditional probabilities for sample 307000 / 325406
# [t-SNE] Computed conditional probabilities for sample 308000 / 325406
# [t-SNE] Computed conditional probabilities for sample 309000 / 325406
# [t-SNE] Computed conditional probabilities for sample 310000 / 325406
# [t-SNE] Computed conditional probabilities for sample 311000 / 325406
# [t-SNE] Computed conditional probabilities for sample 312000 / 325406
# [t-SNE] Computed conditional probabilities for sample 313000 / 325406
# [t-SNE] Computed conditional probabilities for sample 314000 / 325406
# [t-SNE] Computed conditional probabilities for sample 315000 / 325406
# [t-SNE] Computed conditional probabilities for sample 316000 / 325406
# [t-SNE] Computed conditional probabilities for sample 317000 / 325406
# [t-SNE] Computed conditional probabilities for sample 318000 / 325406
# [t-SNE] Computed conditional probabilities for sample 319000 / 325406
# [t-SNE] Computed conditional probabilities for sample 320000 / 325406
# [t-SNE] Computed conditional probabilities for sample 321000 / 325406
# [t-SNE] Computed conditional probabilities for sample 322000 / 325406
# [t-SNE] Computed conditional probabilities for sample 323000 / 325406
# [t-SNE] Computed conditional probabilities for sample 324000 / 325406
# [t-SNE] Computed conditional probabilities for sample 325000 / 325406
# [t-SNE] Computed conditional probabilities for sample 325406 / 325406
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 136.846069
# [t-SNE] KL divergence after 1000 iterations: 5.316459

# %%
df = pd.DataFrame()
df["y"] = y
df["comp-1"] = z[:,0]
df["comp-2"] = z[:,1]

# %%
sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 3),
                data=df).set(title="325406 Articles t-SNE projection")
# Out:
# [Text(0.5, 1.0, '325406 Articles t-SNE projection')]
